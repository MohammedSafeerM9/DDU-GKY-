# %%
#importing modules
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
#importing datasets
df=pd.read_csv("netflix_titles_2021.csv")

# %%
#to show first 10 table coloum
df
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
#to show last 5 elements
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
#to pick random sample
df.sample()
# Out:
#      show_id   type       title      director  \
# 4388   s4389  Movie  Aalorukkam  V C Abhilash
#
#                                                    cast country  \
# 4388  Indrans, Sreekanth Menon, Vishnu Agasthya, Ali...   India
#
#              date_added  release_year rating duration  \
# 4388  November 15, 2018          2018  TV-PG  122 min
#
#                                              listed_in  \
# 4388  Dramas, Independent Movies, International Movies
#
#                                             description
# 4388  When an aging father seeks the help of a docto...

# %%
#to find all coloms details
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.loc[10:15]
# Out:
#    show_id     type                                title             director  \
# 10     s11  TV Show  Vendetta: Truth, Lies and The Mafia                  NaN
# 11     s12  TV Show                     Bangkok Breaking    Kongkiat Komesiri
# 12     s13    Movie                         Je Suis Karl  Christian Schwochow
# 13     s14    Movie     Confessions of an Invisible Girl        Bruno Garotti
# 14     s15  TV Show      Crime Stories: India Detectives                  NaN
# 15     s16  TV Show                    Dear White People                  NaN
#
#                                                  cast  \
# 10                                                NaN
# 11  Sukollawat Kanarot, Sushar Manaying, Pavarit M...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 13  Klara Castanho, Lucca Picon, Júlia Gomes, Marc...
# 14                                                NaN
# 15  Logan Browning, Brandon P. Bell, DeRon Horton,...
#
# ...

# %%
df.duplicated().sum()
# Out:
# 0
